# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/Guillermo-Marin11/Coder-House/main/Agua%20Calidad1.csv'
df= pd.read_csv(url,sep=';',header=None)
df
# Out:
#             0         1         2            3         4             5   \
# 0           Ph  Hardness    Solids  Chloramines   Sulfate  Conductivity
# 1          NaN  2,05E+15  2,08E+16     7,30E+15  3,69E+16      5,64E+15
# 2     3,72E+14  1,29E+16  1,86E+16     6,64E+12       NaN      5,93E+15
# 3     8,10E+15  2,24E+16  1,99E+16     9,28E+15       NaN      4,19E+15
# 4     8,32E+15  2,14E+16  2,20E+16     8,06E+14  3,57E+16      3,63E+15
# ...        ...       ...       ...          ...       ...           ...
# 3272  4,67E+15  1,94E+16  4,76E+15     7,17E+15  3,60E+13      5,26E+15
# 3273  7,81E+16  1,94E+16  1,73E+16     8,06E+15       NaN      3,92E+15
# 3274  9,42E+14  1,76E+16  3,32E+16     7,35E+15       NaN      4,32E+16
# 3275  5,13E+16  2,31E+16  1,20E+16     6,30E+15       NaN      4,03E+14
# 3276  7,87E+15  1,95E+16  1,74E+15     7,51E+15       NaN      3,27E+15
#
#                   6                7          8               9          10  \
# 0     Organic_carbon  Trihalomethanes  Turbidity           Color     Source
# 1           1,04E+14         8,70E+14   2,96E+16       Colorless       Lake
# 2           1,52E+16         5,63E+15   4,50E+15    Faint Yellow      River
# 3           1,69E+16         6,64E+15   3,06E+16    Light Yellow     Ground
# 4           1,84E+16         1,00E+16   4,63E+15  Near Colorless     Spring
# ...              ...              ...        ...             ...        ...
# 3272        1,39E+16         6,67E+15   4,44E+13    Faint Yellow       Well
# 3273        1,99E+15              NaN   2,80E+16    Faint Yellow     Stream
# 3274        1,10E+16         6,98E+15   3,30E+15  Near Colorless      River
# 3275        1,12E+16         7,75E+15   4,71E+15       Colorless  Reservoir
# 3276        1,61E+16         7,87E+15   2,31E+15          Yellow       Well
#
#               11
# 0     Potability
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3272           1
# 3273           1
# 3274           1
# 3275           1
# 3276           1
#
# [3277 rows x 12 columns]

# %% [markdown]
# # **Descripción del dataset:**
#
# 0. ph: Concentración de iones de hidrógeno
# 1. HAR(Hardness): concentración de compuestos minerales
# 2. SOL(Solids): Solidos disueltos en el agua
# 3. CHL(Chloramines): es un compuesto químico (Por lo general se utiliza como una solución diluida con función desinfectante)
# 4. SUL(Sulfate): cantidad de sulfato en el agua (en pequeñas cantidades no son tóxicos)
# 5. CON(Conductivity): conductividad electrica del agua, es la capacidad de la misma para transportar la corriente electrica.
# 6. ORG(Organic_carbon): Presencia de materia organica en el agua
# 7. TRI(Trihalometh): Subproductos de la desifección que se forman cuando se emplea el cloro como desinfectante.
# 8. TUR(Turbidity): La turbidez es una medida de la claridad del agua.
# 9. COL(Color): Color del agua.
# 10. SOU(Source): Fuende de donde se extrajo la muestra.
# 11. POT(Potability): Ptabilidad del agua

# %%
df = df.drop(0)

# %%
# Remombramos las columnas
df= df.rename(columns={0: "PH", 1: "HAR", 2: "SOL", 3: "CHL", 4: "SUL", 5: "CON", 6: "ORG",
                       7: "TRI", 8: "TUR", 9: "COL", 10: "SOU", 11: "POT"})
df
# Out:
#             PH       HAR       SOL       CHL       SUL       CON       ORG  \
# 1          NaN  2,05E+15  2,08E+16  7,30E+15  3,69E+16  5,64E+15  1,04E+14
# 2     3,72E+14  1,29E+16  1,86E+16  6,64E+12       NaN  5,93E+15  1,52E+16
# 3     8,10E+15  2,24E+16  1,99E+16  9,28E+15       NaN  4,19E+15  1,69E+16
# 4     8,32E+15  2,14E+16  2,20E+16  8,06E+14  3,57E+16  3,63E+15  1,84E+16
# 5     9,09E+15  1,81E+16  1,80E+15  6,55E+15  3,10E+16  3,98E+16  1,16E+16
# ...        ...       ...       ...       ...       ...       ...       ...
# 3272  4,67E+15  1,94E+16  4,76E+15  7,17E+15  3,60E+13  5,26E+15  1,39E+16
# 3273  7,81E+16  1,94E+16  1,73E+16  8,06E+15       NaN  3,92E+15  1,99E+15
# 3274  9,42E+14  1,76E+16  3,32E+16  7,35E+15       NaN  4,32E+16  1,10E+16
# 3275  5,13E+16  2,31E+16  1,20E+16  6,30E+15       NaN  4,03E+14  1,12E+16
# 3276  7,87E+15  1,95E+16  1,74E+15  7,51E+15       NaN  3,27E+15  1,61E+16
#
#            TRI       TUR             COL        SOU POT
# 1     8,70E+14  2,96E+16       Colorless       Lake   0
# 2     5,63E+15  4,50E+15    Faint Yellow      River   0
# 3     6,64E+15  3,06E+16    Light Yellow     Ground   0
# 4     1,00E+16  4,63E+15  Near Colorless     Spring   0
# 5     3,20E+16  4,08E+15    Light Yellow     Stream   0
# ...        ...       ...             ...        ...  ..
# 3272  6,67E+15  4,44E+13    Faint Yellow       Well   1
# 3273       NaN  2,80E+16    Faint Yellow     Stream   1
# 3274  6,98E+15  3,30E+15  Near Colorless      River   1
# 3275  7,75E+15  4,71E+15       Colorless  Reservoir   1
# 3276  7,87E+15  2,31E+15          Yellow       Well   1
#
# [3276 rows x 12 columns]

# %%
df["PH"] = df["PH"].str.slice(0,4)
df["HAR"] = df["HAR"].str.slice(0,4)
df["SOL"] = df["SOL"].str.slice(0,4)
df["CHL"] = df["CHL"].str.slice(0,4)
df["SUL"] = df["SUL"].str.slice(0,4)
df["CON"] = df["CON"].str.slice(0,4)
df["ORG"] = df["ORG"].str.slice(0,4)
df["TRI"] = df["TRI"].str.slice(0,4)
df["TUR"] = df["TUR"].str.slice(0,4)
df
# Out:
#         PH   HAR   SOL   CHL   SUL   CON   ORG   TRI   TUR             COL  \
# 1      NaN  2,05  2,08  7,30  3,69  5,64  1,04  8,70  2,96       Colorless
# 2     3,72  1,29  1,86  6,64   NaN  5,93  1,52  5,63  4,50    Faint Yellow
# 3     8,10  2,24  1,99  9,28   NaN  4,19  1,69  6,64  3,06    Light Yellow
# 4     8,32  2,14  2,20  8,06  3,57  3,63  1,84  1,00  4,63  Near Colorless
# 5     9,09  1,81  1,80  6,55  3,10  3,98  1,16  3,20  4,08    Light Yellow
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...             ...
# 3272  4,67  1,94  4,76  7,17  3,60  5,26  1,39  6,67  4,44    Faint Yellow
# 3273  7,81  1,94  1,73  8,06   NaN  3,92  1,99   NaN  2,80    Faint Yellow
# 3274  9,42  1,76  3,32  7,35   NaN  4,32  1,10  6,98  3,30  Near Colorless
# 3275  5,13  2,31  1,20  6,30   NaN  4,03  1,12  7,75  4,71       Colorless
# 3276  7,87  1,95  1,74  7,51   NaN  3,27  1,61  7,87  2,31          Yellow
#
#             SOU POT
# 1          Lake   0
# 2         River   0
# 3        Ground   0
# 4        Spring   0
# 5        Stream   0
# ...         ...  ..
# 3272       Well   1
# 3273     Stream   1
# 3274      River   1
# 3275  Reservoir   1
# 3276       Well   1
#
# [3276 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 1 to 3276
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH      2785 non-null   object
#  1   HAR     3276 non-null   object
#  2   SOL     3276 non-null   object
#  3   CHL     3276 non-null   object
#  4   SUL     2495 non-null   object
#  5   CON     3276 non-null   object
#  6   ORG     3276 non-null   object
#  7   TRI     3114 non-null   object
#  8   TUR     3276 non-null   object
#  9   COL     3276 non-null   object
#  10  SOU     3276 non-null   object
#  11  POT     3276 non-null   object
# dtypes: object(12)
# memory usage: 307.3+ KB

# %%
df.dropna(inplace=True)
df
# Out:
#         PH   HAR   SOL   CHL   SUL   CON   ORG   TRI   TUR             COL  \
# 4     8,32  2,14  2,20  8,06  3,57  3,63  1,84  1,00  4,63  Near Colorless
# 5     9,09  1,81  1,80  6,55  3,10  3,98  1,16  3,20  4,08    Light Yellow
# 6     5,58  1,88  2,87  7,54  3,27  2,80  8,40  5,49  2,56  Near Colorless
# 7     1,02  2,48  2,87  7,51  3,94  2,84  1,38  8,46  2,67    Light Yellow
# 8     8,64  2,03  1,37  4,56  3,03  4,75  1,24  6,28  4,40       Colorless
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...             ...
# 3268  8,99  2,15  1,59  6,30  3,13  3,90  9,90  5,51  4,61  Near Colorless
# 3269  6,70  2,07  1,72  7,71  3,05  3,29  1,62  2,89  3,44  Near Colorless
# 3270  1,15  9,48  3,72  9,26  2,59  4,40  1,62  4,16  4,37       Colorless
# 3271  6,07  1,87  2,61  7,75  3,46  4,16  1,21  6,04  3,67  Near Colorless
# 3272  4,67  1,94  4,76  7,17  3,60  5,26  1,39  6,67  4,44    Faint Yellow
#
#           SOU POT
# 4      Spring   0
# 5      Stream   0
# 6     Aquifer   0
# 7       River   0
# 8      Spring   0
# ...       ...  ..
# 3268   Ground   1
# 3269   Spring   1
# 3270     Lake   1
# 3271   Ground   1
# 3272     Well   1
#
# [2011 rows x 12 columns]

# %%
df_reindexado = df.reset_index(drop=True)
df_reindexado
# Out:
#         PH   HAR   SOL   CHL   SUL   CON   ORG   TRI   TUR             COL  \
# 0     8,32  2,14  2,20  8,06  3,57  3,63  1,84  1,00  4,63  Near Colorless
# 1     9,09  1,81  1,80  6,55  3,10  3,98  1,16  3,20  4,08    Light Yellow
# 2     5,58  1,88  2,87  7,54  3,27  2,80  8,40  5,49  2,56  Near Colorless
# 3     1,02  2,48  2,87  7,51  3,94  2,84  1,38  8,46  2,67    Light Yellow
# 4     8,64  2,03  1,37  4,56  3,03  4,75  1,24  6,28  4,40       Colorless
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...             ...
# 2006  8,99  2,15  1,59  6,30  3,13  3,90  9,90  5,51  4,61  Near Colorless
# 2007  6,70  2,07  1,72  7,71  3,05  3,29  1,62  2,89  3,44  Near Colorless
# 2008  1,15  9,48  3,72  9,26  2,59  4,40  1,62  4,16  4,37       Colorless
# 2009  6,07  1,87  2,61  7,75  3,46  4,16  1,21  6,04  3,67  Near Colorless
# 2010  4,67  1,94  4,76  7,17  3,60  5,26  1,39  6,67  4,44    Faint Yellow
#
#           SOU POT
# 0      Spring   0
# 1      Stream   0
# 2     Aquifer   0
# 3       River   0
# 4      Spring   0
# ...       ...  ..
# 2006   Ground   1
# 2007   Spring   1
# 2008     Lake   1
# 2009   Ground   1
# 2010     Well   1
#
# [2011 rows x 12 columns]

# %%
df = df.replace(',','.', regex=True)
df
# Out:
#         PH   HAR   SOL   CHL   SUL   CON   ORG   TRI   TUR             COL  \
# 4     8.32  2.14  2.20  8.06  3.57  3.63  1.84  1.00  4.63  Near Colorless
# 5     9.09  1.81  1.80  6.55  3.10  3.98  1.16  3.20  4.08    Light Yellow
# 6     5.58  1.88  2.87  7.54  3.27  2.80  8.40  5.49  2.56  Near Colorless
# 7     1.02  2.48  2.87  7.51  3.94  2.84  1.38  8.46  2.67    Light Yellow
# 8     8.64  2.03  1.37  4.56  3.03  4.75  1.24  6.28  4.40       Colorless
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...             ...
# 3268  8.99  2.15  1.59  6.30  3.13  3.90  9.90  5.51  4.61  Near Colorless
# 3269  6.70  2.07  1.72  7.71  3.05  3.29  1.62  2.89  3.44  Near Colorless
# 3270  1.15  9.48  3.72  9.26  2.59  4.40  1.62  4.16  4.37       Colorless
# 3271  6.07  1.87  2.61  7.75  3.46  4.16  1.21  6.04  3.67  Near Colorless
# 3272  4.67  1.94  4.76  7.17  3.60  5.26  1.39  6.67  4.44    Faint Yellow
#
#           SOU POT
# 4      Spring   0
# 5      Stream   0
# 6     Aquifer   0
# 7       River   0
# 8      Spring   0
# ...       ...  ..
# 3268   Ground   1
# 3269   Spring   1
# 3270     Lake   1
# 3271   Ground   1
# 3272     Well   1
#
# [2011 rows x 12 columns]

# %%
#PH,HAR,SOL,CHL,SUL,CON,ORG,TRI,TUR,COL,SOU,POT
df['PH'] = df['PH'].astype(float)
df['HAR'] = df['HAR'].astype(float)
df['SOL'] = df['SOL'].astype(float)
df['CHL'] = df['CHL'].astype(float)
df['SUL'] = df['SUL'].astype(float)
df['CON'] = df['CON'].astype(float)
df['ORG'] = df['ORG'].astype(float)
df['TRI'] = df['TRI'].astype(float)
df['TUR'] = df['TUR'].astype(float)
df['COL'] = df['COL'].astype(str)
df['SOU'] = df['SOU'].astype(str)
df['POT'] = df['POT'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2011 entries, 4 to 3272
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH      2011 non-null   float64
#  1   HAR     2011 non-null   float64
#  2   SOL     2011 non-null   float64
#  3   CHL     2011 non-null   float64
#  4   SUL     2011 non-null   float64
#  5   CON     2011 non-null   float64
#  6   ORG     2011 non-null   float64
#  7   TRI     2011 non-null   float64
#  8   TUR     2011 non-null   float64
#  9   COL     2011 non-null   object
#  10  SOU     2011 non-null   object
#  11  POT     2011 non-null   int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 204.2+ KB

# %%
df.shape
# Out:
# (2011, 12)

# %%
df.describe()
# Out:
#                 PH          HAR          SOL          CHL          SUL  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean      6.730154     1.995912     2.610239     6.837404     3.332069
# std       1.781693     0.571562     1.592420     1.757281     0.412133
# min       1.000000     1.000000     1.010000     1.000000     1.290000
# 25%       5.900000     1.770000     1.690000     6.010000     3.080000
# 50%       6.920000     1.970000     2.230000     7.020000     3.320000
# 75%       7.890000     2.170000     2.900000     7.980000     3.590000
# max       9.970000     9.880000     9.970000     9.990000     4.810000
#
#                CON          ORG          TRI          TUR          POT
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean      4.265316     2.141537     6.456852     3.969657     0.403282
# std       0.807145     2.069726     1.677317     0.780294     0.490678
# min       2.020000     1.000000     1.000000     1.450000     0.000000
# 25%       3.670000     1.290000     5.510000     3.440000     0.000000
# 50%       4.230000     1.520000     6.570000     3.970000     0.000000
# 75%       4.820000     1.780000     7.630000     4.515000     1.000000
# max       7.530000     9.980000     9.990000     6.490000     1.000000

# %%
print(df.isnull().sum())
# Out:
# PH     0
# HAR    0
# SOL    0
# CHL    0
# SUL    0
# CON    0
# ORG    0
# TRI    0
# TUR    0
# COL    0
# SOU    0
# POT    0
# dtype: int64

# %%
conteoxsou = df['SOU'].value_counts()

print(conteoxsou)
# Out:
# SOU
# Ground       276
# Stream       271
# River        265
# Reservoir    256
# Spring       241
# Aquifer      239
# Well         233
# Lake         230
# Name: count, dtype: int64

# %%
sounicos = df['SOU'].unique()
sounicos
# Out:
# array(['Spring', 'Stream', 'Aquifer', 'River', 'Reservoir', 'Lake',
#        'Ground', 'Well'], dtype=object)

# %%
fig,ax = plt.subplots(figsize =(8,7))
fig.set_facecolor('#989AFF')

ax.pie(conteoxsou, labels = sounicos,radius=0.7, startangle=90, autopct="%1.2f%%")
plt.legend(loc="lower right", labels=sounicos,fontsize=9)
plt.show()

# %%
mediaxph = df.groupby('SOU')['PH'].mean().round(2)
mediaxph
# Out:
# SOU
# Aquifer      6.65
# Ground       6.76
# Lake         6.62
# Reservoir    6.72
# River        6.79
# Spring       6.82
# Stream       6.80
# Well         6.64
# Name: PH, dtype: float64

# %%
sns.displot(data=df, x="PH", hue="SOU", col="SOU")

# %%
sns.displot(data=df, x="PH", hue="SOU", kind="kde", multiple="layer", palette="viridis")
plt.show()

# %%
lista_tur = df['TUR'].tolist()
lista_org = df['ORG'].tolist()

# %%
fig, ax = plt.subplots()
ax.scatter(lista_tur, lista_org, alpha=0.7)
ax.set_title('Turbidez VS. Materia orgánica')
ax.set_xlabel('Turbidez')
ax.set_ylabel('Materia orgánica')
# Out:
# Text(0, 0.5, 'Materia orgánica')

# %%
mediaxcol = df.groupby('SOU')[['PH','HAR','SOL','CHL','SUL','CON','ORG','TRI','TUR']].mean().round(2)
print("Media por origen de extracción")
mediaxcol
# Out:
# Media por origen de extracción
#              PH   HAR   SOL   CHL   SUL   CON   ORG   TRI   TUR
# SOU
# Aquifer    6.65  2.02  2.70  6.85  3.38  4.34  2.18  6.38  3.97
# Ground     6.76  1.97  2.64  6.84  3.31  4.27  2.39  6.39  3.99
# Lake       6.62  2.03  2.52  6.72  3.30  4.22  2.08  6.51  3.92
# Reservoir  6.72  1.99  2.53  6.91  3.33  4.27  2.21  6.50  3.96
# River      6.79  2.01  2.71  6.83  3.30  4.17  1.95  6.29  3.99
# Spring     6.82  1.96  2.51  6.74  3.35  4.31  2.21  6.65  4.00
# Stream     6.80  2.01  2.62  6.90  3.33  4.27  2.03  6.42  3.98
# Well       6.64  1.98  2.64  6.88  3.34  4.28  2.06  6.54  3.95
